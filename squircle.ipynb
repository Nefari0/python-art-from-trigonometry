# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
squircle formula:x**4 + y**4 +a**4

example on solving:
    x**4 + y**4 = 1 : where 1 is parameter for a

# %%
x = np.linspace(0,2*np.pi,100)


# atop4 = (np.cos(x**4)) + (np.sin(x**4))

plt.plot(np.cos(x**4),np.sin(x**4),'r-')


# plt.xlim(-1500,1500)
# plt.axis('square')
# atop4

# %%
a = np.linspace(0,2*np.pi,100)

x = np.cbrt(a**4 - y**4)
y = np.cbrt(a**4 - x**4)


plt.plot(x**4,y**4,'ro')
plt.axis('square')
# Out:
# (-2.8026166355363564e+16,
#  5.083750749860609e+23,
#  -2.3107959227828515e+22,
#  4.852671437843988e+23)

# %%
#  y**4 = (1 - x**4)**1/4  : where 1 is parameter for a

x = np.linspace(-1,1,20001)
y = (1 - x**4)**(1/4)

plt.plot(x,y,'k',linewidth=3)
plt.plot(x,-y,'k',linewidth=3)

plt.axis('square')
plt.axis('off')
plt.show()
